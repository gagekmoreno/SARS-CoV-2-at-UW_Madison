# %% [markdown]
# ## Import modules and dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
import glob
import os
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pathlib import Path
from os.path import splitext
from functools import reduce
from pandas.api.types import is_numeric_dtype
import warnings
from pandas.core.common import SettingWithCopyWarning
from matplotlib.font_manager import FontProperties 
from matplotlib import cm
import itertools
from matplotlib import container
from matplotlib import gridspec
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.lines as mlines
import matplotlib as mpl
from pandas.plotting import table
import random
import matplotlib.patches as mpatches
from collections import Counter
import functools
import operator
from itertools import chain
import pandas as pd
import glob, os
import shutil as sh
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pathlib import Path
from os.path import splitext
from functools import reduce
from pandas.api.types import is_numeric_dtype
import warnings
from pandas.core.common import SettingWithCopyWarning
from matplotlib.font_manager import FontProperties 
from matplotlib import cm
import itertools
from matplotlib import container
from matplotlib import gridspec
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.lines as mlines
import matplotlib as mpl
from pandas.plotting import table
from statistics import mean
import statistics

# %%
def load_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.vcf')]
    list_of_DFs = []
    for file in filelist: 
#         print(file)
        DF = path + '/' + file + '.vcf'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False)
        file['sample'] = DF
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

def load_cleaned_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.csv')]
    list_of_DFs = []
    for file in filelist: 
#         print(file)
        DF = path + '/' + file + '.csv'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False)
        file['sample'] = DF
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

# clean up the VCF files and save as CSV files 

def clean_dataframes(path, list_of_DFs):
    if not os.path.exists(path + '/cleaned'):
            os.makedirs(path + '/cleaned')
    for DF in list_of_DFs:
        DF = DF[['sample', 'Position', 'Ref', 'Cons']]
        DF['sample'] = DF['sample'].map(lambda x: x.lstrip('data_raw/VCFs/'))
        DF['sample'] = DF['sample'].map(lambda x: x.rstrip('.fasta.vcf'))
        DF['sample'] = DF['sample'].map(lambda x: x.lstrip('SA_'))
        sample = DF['sample'].values[0]
        DF['Position'] = DF['Position'].apply(str)
        DF['SNP'] = DF['Position'] + '_' + DF['Ref'] + '>' + DF['Cons']
        DF.to_csv(path + 'cleaned/' + sample + '-cleaned.csv', sep='\t')
        
def make_snp_list(path, list_of_DFs):
    list_of_lists = []
    for DF in list_of_DFs:
        DF = DF['SNP'].tolist()
        list_of_lists.append(DF)
    return(list_of_lists)
        

def make_dictionary(path, list_of_DFs):
    names_and_snpies = {}
    for DF in list_of_DFs:
        key = DF['sample'].values[0]
        key = key.strip('VCFs/cleaned//')
        key = key.strip('-cleaned.csv')
        value = DF['SNP'].tolist()
        names_and_snpies[key] = value
    return(names_and_snpies)

def get_unique_snps(path, list_of_DFs):
    all_samples = pd.concat(list_of_DFs)
    all_samples = all_samples.drop(axis=1, columns=['sample','Position','Ref','Cons','Unnamed: 0'])
    all_samples = all_samples.drop_duplicates(keep='first')
    all_samples = all_samples.reset_index()
    all_samples = all_samples.drop(axis=1, columns='index')
    return (all_samples)

# %%
# %%bash
# conda activate nextstrain
# augur filter --sequences data/sequences.fasta --metadata data/metadata.tsv --group-by month year submitting_lab --exclude-where 'campus!=UW-Madison' --output data/UWMadisonDorm.fasta
# Out:
# 4886 sequences were dropped during filtering
# 	4886 of these were dropped because of 'campus!=UW-Madison'
# 278 sequences have been written out to data/UWMadisonDorm.fasta
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# %%bash
# splitfasta UWMadisonDorm.fasta

# %%
# %%bash
#
# for f in UWMadisonDorm_split_files/*; do
#     faidx -x $f
# done

# %%
# %%bash
# mv USA*.fasta dormfiles

# %%
# %%bash
#
# # UW Madison Dorm samples, this takes ~10 mins to run
#
# for file in $(ls dormfiles/*.fasta)
# do
#     bbmap.sh in=$file out=$file.bam ref=ref.fa #map to Wuhan reference
#     samtools sort $file.bam -o $file.bam # sort the bam
#     samtools mpileup -f ref.fa $file.bam > $file.pileup # generate a pileup file
#     java -jar VarScan.jar pileup2snp $file.pileup --min-coverage 1 --min-reads2 1 > $file.vcf
# done
#
# ##
# Out:
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14182020.fasta out=dormfiles/USAWI-UW-14182020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14182020.fasta, out=dormfiles/USAWI-UW-14182020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Deleting contents of ref/genome/1 because reference is specified and overwrite=true
# NOTE:	Deleting contents of ref/index/1 because reference is specified and overwrite=true
# Writing reference.
# Executing dna.FastaToChromArrays2 [ref.fa, 1, writeinthread=false, genscaffoldinfo=true, retain, waitforwriting=false, gz=true, maxlen=536670912, writechroms=true, minscaf=1, midpad=300, startpad=8000, stoppad=8000, nodisk=false]
#
# Set genScaffoldInfo=true
# Writing chunk 1
# Set genome to 1
#
# Loaded Reference:	0.005 seconds.
# Loading index for chunk 1-1, build 1
# No index available; generating from reference genome: /Volumes/GoogleDrive/My Drive/SARS-CoV-2_Sequencing/CDCMadison/ref/index/1/chr1_index_k13_c15_b1.block
# Indexing threads started for block 0-1
# Indexing threads finished for block 0-1
# Generated Index:	1.359 seconds.
# Analyzed Index:   	2.713 seconds.
# Found samtools 1.9
# Started output stream:	0.118 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.758 seconds.
# Reads/sec:       	79.18
# kBases/sec:      	39.30
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 68.3333% 	       41 	 68.8335% 	       20500
# semiperfect site:	 68.3333% 	       41 	 68.8335% 	       20500
#
# Match Rate:      	      NA 	       NA 	 99.9228% 	       29759
# Error Rate:      	 30.0000% 	       18 	  0.0739% 	          22
# Sub Rate:        	 30.0000% 	       18 	  0.0739% 	          22
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	5.243 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14182020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 22 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14192020.fasta out=dormfiles/USAWI-UW-14192020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14192020.fasta, out=dormfiles/USAWI-UW-14192020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.020 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.601 seconds.
# Analyzed Index:   	2.555 seconds.
# Found samtools 1.9
# Started output stream:	0.750 seconds.
# Cleared Memory:    	0.105 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.325 seconds.
# Reads/sec:       	184.51
# kBases/sec:      	91.59
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 81.6667% 	       49 	 81.5325% 	       24282
# semiperfect site:	 81.6667% 	       49 	 81.5325% 	       24282
#
# Match Rate:      	      NA 	       NA 	 99.2244% 	       29551
# Error Rate:      	 15.0000% 	        9 	  0.0403% 	          12
# Sub Rate:        	 15.0000% 	        9 	  0.0403% 	          12
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  3.3333% 	        2 	  0.7353% 	         219
#
# Total time:     	4.471 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14192020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 12 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14202020.fasta out=dormfiles/USAWI-UW-14202020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14202020.fasta, out=dormfiles/USAWI-UW-14202020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.018 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.591 seconds.
# Analyzed Index:   	2.710 seconds.
# Found samtools 1.9
# Started output stream:	0.121 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.301 seconds.
# Reads/sec:       	199.42
# kBases/sec:      	98.98
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 73.3333% 	       44 	 73.8701% 	       22000
# semiperfect site:	 73.3333% 	       44 	 73.8701% 	       22000
#
# Match Rate:      	      NA 	       NA 	 99.2076% 	       29546
# Error Rate:      	 23.3333% 	       14 	  0.0571% 	          17
# Sub Rate:        	 23.3333% 	       14 	  0.0571% 	          17
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  3.3333% 	        2 	  0.7353% 	         219
#
# Total time:     	3.960 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14202020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 17 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14212020.fasta out=dormfiles/USAWI-UW-14212020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14212020.fasta, out=dormfiles/USAWI-UW-14212020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.588 seconds.
# Analyzed Index:   	2.740 seconds.
# Found samtools 1.9
# Started output stream:	0.071 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.432 seconds.
# Reads/sec:       	138.97
# kBases/sec:      	68.98
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 73.3333% 	       44 	 73.8701% 	       22000
# semiperfect site:	 73.3333% 	       44 	 73.8701% 	       22000
#
# Match Rate:      	      NA 	       NA 	 99.9396% 	       29764
# Error Rate:      	 25.0000% 	       15 	  0.0571% 	          17
# Sub Rate:        	 25.0000% 	       15 	  0.0571% 	          17
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.082 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14212020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 17 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14222020.fasta out=dormfiles/USAWI-UW-14222020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14222020.fasta, out=dormfiles/USAWI-UW-14222020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.019 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.590 seconds.
# Analyzed Index:   	2.537 seconds.
# Found samtools 1.9
# Started output stream:	0.557 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.259 seconds.
# Reads/sec:       	232.06
# kBases/sec:      	115.19
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 73.3333% 	       44 	 73.1381% 	       21782
# semiperfect site:	 73.3333% 	       44 	 73.1381% 	       21782
#
# Match Rate:      	      NA 	       NA 	 99.9463% 	       29766
# Error Rate:      	 25.0000% 	       15 	  0.0504% 	          15
# Sub Rate:        	 25.0000% 	       15 	  0.0504% 	          15
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.185 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14222020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 15 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14232020.fasta out=dormfiles/USAWI-UW-14232020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14232020.fasta, out=dormfiles/USAWI-UW-14232020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.018 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.604 seconds.
# Analyzed Index:   	2.515 seconds.
# Found samtools 1.9
# Started output stream:	0.400 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.277 seconds.
# Reads/sec:       	216.96
# kBases/sec:      	107.69
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 68.3333% 	       41 	 68.8335% 	       20500
# semiperfect site:	 68.3333% 	       41 	 68.8335% 	       20500
#
# Match Rate:      	      NA 	       NA 	 99.1908% 	       29541
# Error Rate:      	 28.3333% 	       17 	  0.0739% 	          22
# Sub Rate:        	 28.3333% 	       17 	  0.0739% 	          22
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  3.3333% 	        2 	  0.7353% 	         219
#
# Total time:     	4.028 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14232020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 22 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14242020.fasta out=dormfiles/USAWI-UW-14242020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14242020.fasta, out=dormfiles/USAWI-UW-14242020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.021 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.604 seconds.
# Analyzed Index:   	2.857 seconds.
# Found samtools 1.9
# Started output stream:	0.249 seconds.
# Cleared Memory:    	0.105 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29611 bases)
#
# Mapping:          	0.415 seconds.
# Reads/sec:       	144.44
# kBases/sec:      	71.29
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29611
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29611
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 65.0000% 	       39 	 64.5402% 	       19111
# semiperfect site:	 65.0000% 	       39 	 64.5402% 	       19111
#
# Match Rate:      	      NA 	       NA 	 99.1760% 	       29367
# Error Rate:      	 13.3333% 	        8 	  0.0304% 	           9
# Sub Rate:        	 13.3333% 	        8 	  0.0304% 	           9
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	 25.0000% 	       15 	  0.7936% 	         235
#
# Total time:     	4.370 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14242020.fasta.pileup
# 29611 bases in pileup file
# 29611 met minimum coverage of 1x
# 9 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14252020.fasta out=dormfiles/USAWI-UW-14252020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14252020.fasta, out=dormfiles/USAWI-UW-14252020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.021 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.605 seconds.
# Analyzed Index:   	3.082 seconds.
# Found samtools 1.9
# Started output stream:	0.073 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.366 seconds.
# Reads/sec:       	164.03
# kBases/sec:      	81.42
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 63.3333% 	       38 	 63.7969% 	       19000
# semiperfect site:	 63.3333% 	       38 	 63.7969% 	       19000
#
# Match Rate:      	      NA 	       NA 	 99.1841% 	       29539
# Error Rate:      	 25.0000% 	       15 	  0.0571% 	          17
# Sub Rate:        	 25.0000% 	       15 	  0.0571% 	          17
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	 15.0000% 	        9 	  0.7588% 	         226
#
# Total time:     	4.380 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14252020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 17 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14262020.fasta out=dormfiles/USAWI-UW-14262020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14262020.fasta, out=dormfiles/USAWI-UW-14262020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.022 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.648 seconds.
# Analyzed Index:   	2.724 seconds.
# Found samtools 1.9
# Started output stream:	0.347 seconds.
# Cleared Memory:    	0.106 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.329 seconds.
# Reads/sec:       	182.15
# kBases/sec:      	90.41
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 73.3333% 	       44 	 73.1381% 	       21782
# semiperfect site:	 73.3333% 	       44 	 73.1381% 	       21782
#
# Match Rate:      	      NA 	       NA 	 99.9429% 	       29765
# Error Rate:      	 23.3333% 	       14 	  0.0470% 	          14
# Sub Rate:        	 23.3333% 	       14 	  0.0470% 	          14
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  5.0000% 	        3 	  0.0101% 	           3
#
# Total time:     	4.298 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14262020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 14 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14272020.fasta out=dormfiles/USAWI-UW-14272020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14272020.fasta, out=dormfiles/USAWI-UW-14272020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.022 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.650 seconds.
# Analyzed Index:   	2.655 seconds.
# Found samtools 1.9
# Started output stream:	0.216 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.374 seconds.
# Reads/sec:       	160.60
# kBases/sec:      	79.72
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 70.0000% 	       42 	 70.5124% 	       21000
# semiperfect site:	 70.0000% 	       42 	 70.5124% 	       21000
#
# Match Rate:      	      NA 	       NA 	 99.9261% 	       29760
# Error Rate:      	 28.3333% 	       17 	  0.0705% 	          21
# Sub Rate:        	 28.3333% 	       17 	  0.0705% 	          21
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.146 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14272020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 21 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14282020.fasta out=dormfiles/USAWI-UW-14282020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14282020.fasta, out=dormfiles/USAWI-UW-14282020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.022 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.595 seconds.
# Analyzed Index:   	2.569 seconds.
# Found samtools 1.9
# Started output stream:	0.164 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.276 seconds.
# Reads/sec:       	217.60
# kBases/sec:      	108.01
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 68.3333% 	       41 	 68.8335% 	       20500
# semiperfect site:	 68.3333% 	       41 	 68.8335% 	       20500
#
# Match Rate:      	      NA 	       NA 	 99.1908% 	       29541
# Error Rate:      	 28.3333% 	       17 	  0.0705% 	          21
# Sub Rate:        	 28.3333% 	       17 	  0.0705% 	          21
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  5.0000% 	        3 	  0.7387% 	         220
#
# Total time:     	3.855 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14282020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 21 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14292020.fasta out=dormfiles/USAWI-UW-14292020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14292020.fasta, out=dormfiles/USAWI-UW-14292020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.019 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.598 seconds.
# Analyzed Index:   	2.616 seconds.
# Found samtools 1.9
# Started output stream:	0.065 seconds.
# Cleared Memory:    	0.108 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.460 seconds.
# Reads/sec:       	130.57
# kBases/sec:      	64.81
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 81.6667% 	       49 	 81.5325% 	       24282
# semiperfect site:	 81.6667% 	       49 	 81.5325% 	       24282
#
# Match Rate:      	      NA 	       NA 	 99.9597% 	       29770
# Error Rate:      	 16.6667% 	       10 	  0.0369% 	          11
# Sub Rate:        	 16.6667% 	       10 	  0.0369% 	          11
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	3.978 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14292020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 11 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14302020.fasta out=dormfiles/USAWI-UW-14302020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14302020.fasta, out=dormfiles/USAWI-UW-14302020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.019 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.603 seconds.
# Analyzed Index:   	2.619 seconds.
# Found samtools 1.9
# Started output stream:	0.068 seconds.
# Cleared Memory:    	0.107 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.716 seconds.
# Reads/sec:       	83.76
# kBases/sec:      	41.58
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 73.3333% 	       44 	 73.8701% 	       22000
# semiperfect site:	 73.3333% 	       44 	 73.8701% 	       22000
#
# Match Rate:      	      NA 	       NA 	 99.2076% 	       29546
# Error Rate:      	 23.3333% 	       14 	  0.0504% 	          15
# Sub Rate:        	 23.3333% 	       14 	  0.0504% 	          15
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  6.6667% 	        4 	  0.7421% 	         221
#
# Total time:     	4.239 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14302020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 15 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14312020.fasta out=dormfiles/USAWI-UW-14312020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14312020.fasta, out=dormfiles/USAWI-UW-14312020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.019 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.593 seconds.
# Analyzed Index:   	2.586 seconds.
# Found samtools 1.9
# Started output stream:	0.071 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.372 seconds.
# Reads/sec:       	161.24
# kBases/sec:      	80.03
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 85.0000% 	       51 	 84.8902% 	       25282
# semiperfect site:	 85.0000% 	       51 	 84.8902% 	       25282
#
# Match Rate:      	      NA 	       NA 	 99.9597% 	       29770
# Error Rate:      	 15.0000% 	        9 	  0.0403% 	          12
# Sub Rate:        	 15.0000% 	        9 	  0.0403% 	          12
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	3.858 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14312020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 12 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-14322020.fasta out=dormfiles/USAWI-UW-14322020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-14322020.fasta, out=dormfiles/USAWI-UW-14322020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.022 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.886 seconds.
# Analyzed Index:   	2.720 seconds.
# Found samtools 1.9
# Started output stream:	0.078 seconds.
# Cleared Memory:    	0.107 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.899 seconds.
# Reads/sec:       	66.71
# kBases/sec:      	33.11
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 76.6667% 	       46 	 76.4959% 	       22782
# semiperfect site:	 76.6667% 	       46 	 76.4959% 	       22782
#
# Match Rate:      	      NA 	       NA 	 99.2210% 	       29550
# Error Rate:      	 16.6667% 	       10 	  0.0369% 	          11
# Sub Rate:        	 16.6667% 	       10 	  0.0369% 	          11
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  6.6667% 	        4 	  0.7421% 	         221
#
# Total time:     	4.829 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-14322020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 11 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-16302020.fasta out=dormfiles/USAWI-UW-16302020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-16302020.fasta, out=dormfiles/USAWI-UW-16302020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.021 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.607 seconds.
# Analyzed Index:   	2.777 seconds.
# Found samtools 1.9
# Started output stream:	0.077 seconds.
# Cleared Memory:    	0.107 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.367 seconds.
# Reads/sec:       	163.56
# kBases/sec:      	81.19
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	 93.3333% 	       56 	 93.2845% 	       27782
# unambiguous:     	 93.3333% 	       56 	 93.2845% 	       27782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  3.3333% 	        2 	  3.3577% 	        1000
#
# perfect best site:	 65.0000% 	       39 	 65.4758% 	       19500
# semiperfect site:	 65.0000% 	       39 	 65.4758% 	       19500
#
# Match Rate:      	      NA 	       NA 	 97.1240% 	       26983
# Error Rate:      	 17.2414% 	       10 	  0.0360% 	          10
# Sub Rate:        	 17.2414% 	       10 	  0.0360% 	          10
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	 17.2414% 	       10 	  2.8400% 	         789
#
# Total time:     	4.077 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-UW-16302020.fasta.pileup
# 27782 bases in pileup file
# 27782 met minimum coverage of 1x
# 10 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-UW-16312020.fasta out=dormfiles/USAWI-UW-16312020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-UW-16312020.fasta, out=dormfiles/USAWI-UW-16312020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.019 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.590 seconds.
# Analyzed Index:   	2.571 seconds.
# Found samtools 1.9
# Started output stream:	0.605 seconds.
# ...
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.444 seconds.
# Reads/sec:       	135.26
# kBases/sec:      	67.14
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 70.0000% 	       42 	 70.5124% 	       21000
# semiperfect site:	 70.0000% 	       42 	 70.5124% 	       21000
#
# Match Rate:      	      NA 	       NA 	 99.1975% 	       29543
# Error Rate:      	 28.3333% 	       17 	  0.0705% 	          21
# Sub Rate:        	 28.3333% 	       17 	  0.0705% 	          21
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.7320% 	         218
#
# Total time:     	3.953 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-WSLH-2007362020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 21 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-WSLH-2007372020.fasta out=dormfiles/USAWI-WSLH-2007372020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-WSLH-2007372020.fasta, out=dormfiles/USAWI-WSLH-2007372020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.021 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.620 seconds.
# Analyzed Index:   	2.623 seconds.
# Found samtools 1.9
# Started output stream:	0.237 seconds.
# Cleared Memory:    	0.106 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.340 seconds.
# Reads/sec:       	176.49
# kBases/sec:      	87.60
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 70.0000% 	       42 	 69.7804% 	       20782
# semiperfect site:	 70.0000% 	       42 	 69.7804% 	       20782
#
# Match Rate:      	      NA 	       NA 	 99.2076% 	       29546
# Error Rate:      	 28.3333% 	       17 	  0.0604% 	          18
# Sub Rate:        	 28.3333% 	       17 	  0.0604% 	          18
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.7320% 	         218
#
# Total time:     	4.069 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-WSLH-2007372020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 18 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-WSLH-2007382020.fasta out=dormfiles/USAWI-WSLH-2007382020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-WSLH-2007382020.fasta, out=dormfiles/USAWI-WSLH-2007382020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.635 seconds.
# Analyzed Index:   	2.734 seconds.
# Found samtools 1.9
# Started output stream:	0.084 seconds.
# Cleared Memory:    	0.106 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.320 seconds.
# Reads/sec:       	187.45
# kBases/sec:      	93.05
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 68.3333% 	       41 	 68.8335% 	       20500
# semiperfect site:	 68.3333% 	       41 	 68.8335% 	       20500
#
# Match Rate:      	      NA 	       NA 	 99.1908% 	       29541
# Error Rate:      	 30.0000% 	       18 	  0.0772% 	          23
# Sub Rate:        	 30.0000% 	       18 	  0.0772% 	          23
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.7320% 	         218
#
# Total time:     	4.048 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-WSLH-2007382020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 23 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-WSLH-2007392020.fasta out=dormfiles/USAWI-WSLH-2007392020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-WSLH-2007392020.fasta, out=dormfiles/USAWI-WSLH-2007392020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.022 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.598 seconds.
# Analyzed Index:   	2.603 seconds.
# Found samtools 1.9
# Started output stream:	0.069 seconds.
# Cleared Memory:    	0.106 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.253 seconds.
# Reads/sec:       	237.45
# kBases/sec:      	117.86
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 81.6667% 	       49 	 81.5325% 	       24282
# semiperfect site:	 81.6667% 	       49 	 81.5325% 	       24282
#
# Match Rate:      	      NA 	       NA 	 99.9597% 	       29770
# Error Rate:      	 18.3333% 	       11 	  0.0403% 	          12
# Sub Rate:        	 18.3333% 	       11 	  0.0403% 	          12
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	3.778 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-WSLH-2007392020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 12 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-WSLH-2007412020.fasta out=dormfiles/USAWI-WSLH-2007412020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-WSLH-2007412020.fasta, out=dormfiles/USAWI-WSLH-2007412020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.020 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.603 seconds.
# Analyzed Index:   	2.523 seconds.
# Found samtools 1.9
# Started output stream:	0.084 seconds.
# Cleared Memory:    	0.106 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.345 seconds.
# Reads/sec:       	173.92
# kBases/sec:      	86.33
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 66.6667% 	       40 	 66.4227% 	       19782
# semiperfect site:	 66.6667% 	       40 	 66.4227% 	       19782
#
# Match Rate:      	      NA 	       NA 	 99.1035% 	       29515
# Error Rate:      	 30.0000% 	       18 	  0.0638% 	          19
# Sub Rate:        	 30.0000% 	       18 	  0.0638% 	          19
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  3.3333% 	        2 	  0.8327% 	         248
#
# Total time:     	3.807 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-WSLH-2007412020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 19 SNPs predicted
# /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx3200m -Xms3200m -cp /Users/gagemoreno/opt/anaconda3/opt/bbmap-38.84-0/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=dormfiles/USAWI-WSLH-2007422020.fasta out=dormfiles/USAWI-WSLH-2007422020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=dormfiles/USAWI-WSLH-2007422020.fasta, out=dormfiles/USAWI-WSLH-2007422020.fasta.bam, ref=ref.fa]
# Version 38.84
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.019 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.602 seconds.
# Analyzed Index:   	2.635 seconds.
# Found samtools 1.9
# Started output stream:	0.170 seconds.
# Cleared Memory:    	0.106 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 8 mapping threads.
# Detecting finished threads: 0, 1, 2, 3, 4, 5, 6, 7
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.264 seconds.
# Reads/sec:       	227.66
# kBases/sec:      	113.00
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 75.0000% 	       45 	 75.5490% 	       22500
# semiperfect site:	 75.0000% 	       45 	 75.5490% 	       22500
#
# Match Rate:      	      NA 	       NA 	 99.2143% 	       29548
# Error Rate:      	 23.3333% 	       14 	  0.0537% 	          16
# Sub Rate:        	 23.3333% 	       14 	  0.0537% 	          16
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.7320% 	         218
#
# Total time:     	3.920 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from dormfiles/USAWI-WSLH-2007422020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 16 SNPs predicted

# %%
# move *.vcf files from dormfiles to data_derived (in consensus_SNVs)
# Dorms

root_path = "dormfiles/"
dest_path = "VCFs/"

for dirpath, dnames, fnames in os.walk(root_path):    
    for f in fnames:
        if f.endswith(".vcf"):
            source_file_path =  os.path.join(dirpath, f)
            dest_file_path   =  os.path.join(dest_path, f)
            sh.copyfile(source_file_path, dest_file_path)

# %%
# dormfiles cleanup 

dir_name = "dormfiles/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".bam"):
        os.remove(os.path.join(dir_name, item))
        
for item in test:
    if item.endswith(".pileup"):
        os.remove(os.path.join(dir_name, item))
        
for item in test:
    if item.endswith(".vcf"):
        os.remove(os.path.join(dir_name, item))

# %%
list_of_DFs=load_dataframes('VCFs/')
# Out:
# ['USAWI-UW-14182020.fasta', 'USAWI-UW-14192020.fasta', 'USAWI-UW-14202020.fasta', 'USAWI-UW-14212020.fasta', 'USAWI-UW-14222020.fasta', 'USAWI-UW-14232020.fasta', 'USAWI-UW-14242020.fasta', 'USAWI-UW-14252020.fasta', 'USAWI-UW-14262020.fasta', 'USAWI-UW-14272020.fasta', 'USAWI-UW-14282020.fasta', 'USAWI-UW-14292020.fasta', 'USAWI-UW-14302020.fasta', 'USAWI-UW-14312020.fasta', 'USAWI-UW-14322020.fasta', 'USAWI-UW-16302020.fasta', 'USAWI-UW-16312020.fasta', 'USAWI-UW-16322020.fasta', 'USAWI-UW-16332020.fasta', 'USAWI-UW-16342020.fasta', 'USAWI-UW-16352020.fasta', 'USAWI-UW-16362020.fasta', 'USAWI-UW-16372020.fasta', 'USAWI-UW-16382020.fasta', 'USAWI-UW-16392020.fasta', 'USAWI-UW-16402020.fasta', 'USAWI-UW-16412020.fasta', 'USAWI-UW-16422020.fasta', 'USAWI-UW-16432020.fasta', 'USAWI-UW-16442020.fasta', 'USAWI-UW-16452020.fasta', 'USAWI-UW-16462020.fasta', 'USAWI-UW-16472020.fasta', 'USAWI-UW-16482020.fasta', 'USAWI-UW-16492020.fasta', 'USAWI-UW-16502020.fasta', 'USAWI-UW-16512020.fasta', 'USAWI-UW-16522020.fasta', 'USAWI-UW-16532020.fasta', 'USAWI-UW-16542020.fasta', 'USAWI-UW-16552020.fasta', 'USAWI-UW-16562020.fasta', 'USAWI-UW-16572020.fasta', 'USAWI-UW-16582020.fasta', 'USAWI-UW-16592020.fasta', 'USAWI-UW-16602020.fasta', 'USAWI-UW-16612020.fasta', 'USAWI-UW-16622020.fasta', 'USAWI-UW-16632020.fasta', 'USAWI-UW-16642020.fasta', 'USAWI-UW-16652020.fasta', 'USAWI-UW-16662020.fasta', 'USAWI-UW-16672020.fasta', 'USAWI-UW-16682020.fasta', 'USAWI-UW-16692020.fasta', 'USAWI-UW-16702020.fasta', 'USAWI-UW-16712020.fasta', 'USAWI-UW-16722020.fasta', 'USAWI-UW-16732020.fasta', 'USAWI-UW-16742020.fasta', 'USAWI-UW-16752020.fasta', 'USAWI-UW-16762020.fasta', 'USAWI-UW-16772020.fasta', 'USAWI-UW-16782020.fasta', 'USAWI-UW-16792020.fasta', 'USAWI-UW-16802020.fasta', 'USAWI-UW-16812020.fasta', 'USAWI-UW-16822020.fasta', 'USAWI-UW-16832020.fasta', 'USAWI-UW-16842020.fasta', 'USAWI-UW-16852020.fasta', 'USAWI-UW-16862020.fasta', 'USAWI-UW-16872020.fasta', 'USAWI-UW-16882020.fasta', 'USAWI-UW-16892020.fasta', 'USAWI-UW-16902020.fasta', 'USAWI-UW-16912020.fasta', 'USAWI-UW-16922020.fasta', 'USAWI-UW-16932020.fasta', 'USAWI-UW-16942020.fasta', 'USAWI-UW-16952020.fasta', 'USAWI-UW-16962020.fasta', 'USAWI-UW-16972020.fasta', 'USAWI-UW-16982020.fasta', 'USAWI-UW-16992020.fasta', 'USAWI-UW-17002020.fasta', 'USAWI-UW-17012020.fasta', 'USAWI-UW-17022020.fasta', 'USAWI-UW-17032020.fasta', 'USAWI-UW-17042020.fasta', 'USAWI-UW-17052020.fasta', 'USAWI-UW-17062020.fasta', 'USAWI-UW-17072020.fasta', 'USAWI-UW-17082020.fasta', 'USAWI-UW-17092020.fasta', 'USAWI-UW-17102020.fasta', 'USAWI-UW-17112020.fasta', 'USAWI-UW-17122020.fasta', 'USAWI-UW-17132020.fasta', 'USAWI-UW-17142020.fasta', 'USAWI-UW-17152020.fasta', 'USAWI-UW-17162020.fasta', 'USAWI-UW-17172020.fasta', 'USAWI-UW-17182020.fasta', 'USAWI-UW-17192020.fasta', 'USAWI-UW-17202020.fasta', 'USAWI-UW-17212020.fasta', 'USAWI-UW-17222020.fasta', 'USAWI-UW-17232020.fasta', 'USAWI-UW-17242020.fasta', 'USAWI-UW-17252020.fasta', 'USAWI-UW-17262020.fasta', 'USAWI-UW-17272020.fasta', 'USAWI-UW-17282020.fasta', 'USAWI-UW-17292020.fasta', 'USAWI-UW-17302020.fasta', 'USAWI-UW-17312020.fasta', 'USAWI-UW-17322020.fasta', 'USAWI-UW-17332020.fasta', 'USAWI-UW-17342020.fasta', 'USAWI-UW-17352020.fasta', 'USAWI-UW-17362020.fasta', 'USAWI-UW-17372020.fasta', 'USAWI-UW-17382020.fasta', 'USAWI-UW-17392020.fasta', 'USAWI-UW-17402020.fasta', 'USAWI-UW-17412020.fasta', 'USAWI-UW-17422020.fasta', 'USAWI-UW-17432020.fasta', 'USAWI-UW-17442020.fasta', 'USAWI-UW-17452020.fasta', 'USAWI-UW-17462020.fasta', 'USAWI-UW-17472020.fasta', 'USAWI-UW-17482020.fasta', 'USAWI-UW-17492020.fasta', 'USAWI-UW-17502020.fasta', 'USAWI-UW-17512020.fasta', 'USAWI-UW-17522020.fasta', 'USAWI-UW-17532020.fasta', 'USAWI-UW-17542020.fasta', 'USAWI-UW-17552020.fasta', 'USAWI-UW-17562020.fasta', 'USAWI-UW-17572020.fasta', 'USAWI-UW-17582020.fasta', 'USAWI-UW-17592020.fasta', 'USAWI-UW-17602020.fasta', 'USAWI-UW-17612020.fasta', 'USAWI-UW-17622020.fasta', 'US ...

# %%
clean_dataframes('VCFS/', list_of_DFs)
# Out:
# /Users/gagemoreno/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/gagemoreno/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/gagemoreno/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/gagemoreno/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/gagemoreno/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cleaned = load_cleaned_dataframes('VCFs/cleaned/')
# Out:
# ['USAWI-UW-14182020-cleaned', 'USAWI-UW-14192020-cleaned', 'USAWI-UW-14202020-cleaned', 'USAWI-UW-14212020-cleaned', 'USAWI-UW-14222020-cleaned', 'USAWI-UW-14232020-cleaned', 'USAWI-UW-14242020-cleaned', 'USAWI-UW-14252020-cleaned', 'USAWI-UW-14262020-cleaned', 'USAWI-UW-14272020-cleaned', 'USAWI-UW-14282020-cleaned', 'USAWI-UW-14292020-cleaned', 'USAWI-UW-14302020-cleaned', 'USAWI-UW-14312020-cleaned', 'USAWI-UW-14322020-cleaned', 'USAWI-UW-16302020-cleaned', 'USAWI-UW-16312020-cleaned', 'USAWI-UW-16322020-cleaned', 'USAWI-UW-16332020-cleaned', 'USAWI-UW-16342020-cleaned', 'USAWI-UW-16352020-cleaned', 'USAWI-UW-16362020-cleaned', 'USAWI-UW-16372020-cleaned', 'USAWI-UW-16382020-cleaned', 'USAWI-UW-16392020-cleaned', 'USAWI-UW-16402020-cleaned', 'USAWI-UW-16412020-cleaned', 'USAWI-UW-16422020-cleaned', 'USAWI-UW-16432020-cleaned', 'USAWI-UW-16442020-cleaned', 'USAWI-UW-16452020-cleaned', 'USAWI-UW-16462020-cleaned', 'USAWI-UW-16472020-cleaned', 'USAWI-UW-16482020-cleaned', 'USAWI-UW-16492020-cleaned', 'USAWI-UW-16502020-cleaned', 'USAWI-UW-16512020-cleaned', 'USAWI-UW-16522020-cleaned', 'USAWI-UW-16532020-cleaned', 'USAWI-UW-16542020-cleaned', 'USAWI-UW-16552020-cleaned', 'USAWI-UW-16562020-cleaned', 'USAWI-UW-16572020-cleaned', 'USAWI-UW-16582020-cleaned', 'USAWI-UW-16592020-cleaned', 'USAWI-UW-16602020-cleaned', 'USAWI-UW-16612020-cleaned', 'USAWI-UW-16622020-cleaned', 'USAWI-UW-16632020-cleaned', 'USAWI-UW-16642020-cleaned', 'USAWI-UW-16652020-cleaned', 'USAWI-UW-16662020-cleaned', 'USAWI-UW-16672020-cleaned', 'USAWI-UW-16682020-cleaned', 'USAWI-UW-16692020-cleaned', 'USAWI-UW-16702020-cleaned', 'USAWI-UW-16712020-cleaned', 'USAWI-UW-16722020-cleaned', 'USAWI-UW-16732020-cleaned', 'USAWI-UW-16742020-cleaned', 'USAWI-UW-16752020-cleaned', 'USAWI-UW-16762020-cleaned', 'USAWI-UW-16772020-cleaned', 'USAWI-UW-16782020-cleaned', 'USAWI-UW-16792020-cleaned', 'USAWI-UW-16802020-cleaned', 'USAWI-UW-16812020-cleaned', 'USAWI-UW-16822020-cleaned', 'USAWI-UW-16832020-cleaned', 'USAWI-UW-16842020-cleaned', 'USAWI-UW-16852020-cleaned', 'USAWI-UW-16862020-cleaned', 'USAWI-UW-16872020-cleaned', 'USAWI-UW-16882020-cleaned', 'USAWI-UW-16892020-cleaned', 'USAWI-UW-16902020-cleaned', 'USAWI-UW-16912020-cleaned', 'USAWI-UW-16922020-cleaned', 'USAWI-UW-16932020-cleaned', 'USAWI-UW-16942020-cleaned', 'USAWI-UW-16952020-cleaned', 'USAWI-UW-16962020-cleaned', 'USAWI-UW-16972020-cleaned', 'USAWI-UW-16982020-cleaned', 'USAWI-UW-16992020-cleaned', 'USAWI-UW-17002020-cleaned', 'USAWI-UW-17012020-cleaned', 'USAWI-UW-17022020-cleaned', 'USAWI-UW-17032020-cleaned', 'USAWI-UW-17042020-cleaned', 'USAWI-UW-17052020-cleaned', 'USAWI-UW-17062020-cleaned', 'USAWI-UW-17072020-cleaned', 'USAWI-UW-17082020-cleaned', 'USAWI-UW-17092020-cleaned', 'USAWI-UW-17102020-cleaned', 'USAWI-UW-17112020-cleaned', 'USAWI-UW-17122020-cleaned', 'USAWI-UW-17132020-cleaned', 'USAWI-UW-17142020-cleaned', 'USAWI-UW-17152020-cleaned', 'USAWI-UW-17162020-cleaned', 'USAWI-UW-17172020-cleaned', 'USAWI-UW-17182020-cleaned', 'USAWI-UW-17192020-cleaned', 'USAWI-UW-17202020-cleaned', 'USAWI-UW-17212020-cleaned', 'USAWI-UW-17222020-cleaned', 'USAWI-UW-17232020-cleaned', 'USAWI-UW-17242020-cleaned', 'USAWI-UW-17252020-cleaned', 'USAWI-UW-17262020-cleaned', 'USAWI-UW-17272020-cleaned', 'USAWI-UW-17282020-cleaned', 'USAWI-UW-17292020-cleaned', 'USAWI-UW-17302020-cleaned', 'USAWI-UW-17312020-cleaned', 'USAWI-UW-17322020-cleaned', 'USAWI-UW-17332020-cleaned', 'USAWI-UW-17342020-cleaned', 'USAWI-UW-17352020-cleaned', 'USAWI-UW-17362020-cleaned', 'USAWI-UW-17372020-cleaned', 'USAWI-UW-17382020-cleaned', 'USAWI-UW-17392020-cleaned', 'USAWI-UW-17402020-cleaned', 'USAWI-UW-17412020-cleaned', 'USAWI-UW-17422020-cleaned', 'USAWI-UW-17432020-cleaned', 'USAWI-UW-17442020-cleaned', 'USAWI-UW-17452020-cleaned', 'USAWI-UW-17462020-cleaned', 'USAWI-UW-17472020-cleaned', 'USAWI-UW-17482020-cleaned', 'USAWI-UW-17492020-cleaned', 'USAWI-UW-17502020-cleaned', 'USAWI-UW-17512020-cleaned', 'USAWI-UW-17522020-cleaned ...

# %%
list_of_snps = make_snp_list('VCFs/Cleaned/', cleaned)

# %%
snps_in_dorms = make_dictionary('VCFs/Cleaned/', cleaned)

# %%
snps_in_dorms
# Out:
# {'USAWI-UW-14182020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6793_G>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14192020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '14634_A>G',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '28892_C>T'],
#  'USAWI-UW-14202020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14212020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14222020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-14232020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14242020': ['241_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '5672_C>T',
#   '14408_C>T',
#   '16260_C>T',
#   '23126_G>T',
#   '23403_A>G',
#   '25563_G>T'],
#  'USAWI-UW-14252020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '15672_G>T',
#   '16260_C>T',
#   '23126_G>T',
#   '23403_A>G',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '27403_A>G',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14262020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-14272020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14282020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14292020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-14302020': ['241_C>T',
#   '664_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-14312020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '14634_A>G',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '28892_C>T'],
#  'USAWI-UW-14322020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '25609_C>A',
#   '28977_C>T'],
#  'USAWI-UW-16302020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '15654_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '24253_A>T',
#   '25563_G>T',
#   '29808_G>T'],
#  'USAWI-UW-16312020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16322020': ['241_C>T',
#   '681_A>G',
#   '696_A>C',
#   '3037_C>T',
#   '3821_C>A',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5055_C>T',
#   '5672_C>T',
#   '7837_A>C',
#   '8658_A>G',
#   '14408_C>T',
#   '14700_T>C',
#   '16647_G>C',
#   '23120_G>T',
#   '23403_A>G',
#   '25854_C>T',
#   '28977_C>T'],
#  'USAWI-UW-16332020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16342020': ['241_C>T',
#   '664_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '12065_A>G',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16352020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16362020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16372020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16382020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17977_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16392020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '10277_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16402020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-16412020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16422020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16432020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13045_G>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16442020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '29402_G>T'],
#  'USAWI-UW-16452020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16462020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16472020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-16482020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16492020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16502020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16512020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16522020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4596_C>A',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '26801_C>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16532020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16542020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16552020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16562020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16572020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16582020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29362_C>T',
#   '29808_G>T'],
#  'USAWI-UW-16592020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28468_A>C',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16602020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '7420_C>T',
#   '11029_G>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29005_A>T',
#   '29808_G>T'],
#  'USAWI-UW-16612020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16622020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '22015_T>C',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-16632020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16642020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16652020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16662020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16672020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6166_G>A',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-16682020': ['241_C>T',
#   '3037_C>T',
#   '4113_C>T',
#   '5907_C>T',
#   '14408_C>T',
#   '23191_C>T',
#   '23403_A>G'],
#  'USAWI-UW-16692020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16702020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16712020': ['241_C>T',
#   '696_A>C',
#   '2037_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6419_G>A',
#   '7837_A>C',
#   '11541_T>G',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '25947_G>T',
#   '28977_C>T',
#   '29742_G>A'],
#  'USAWI-UW-16722020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-16732020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '14634_A>G',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '28892_C>T'],
#  'USAWI-UW-16742020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16752020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16762020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '23403_A>G',
#   '25563_G>T'],
#  'USAWI-UW-16772020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16782020': ['241_C>T',
#   '1059_C>T',
#   '6793_G>T',
#   '7086_C>T',
#   '14408_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '29808_G>T'],
#  'USAWI-UW-16792020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6793_G>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16802020': ['241_C>T',
#   '1059_C>T',
#   '14408_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '25563_G>T'],
#  'USAWI-UW-16812020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '18369_T>C',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16822020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16832020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-16842020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '8577_A>G',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16852020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16862020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '28952_T>G'],
#  'USAWI-UW-16872020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16882020': ['241_C>T',
#   '664_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16892020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-16902020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-16912020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6793_G>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16922020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16932020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16942020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16952020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-16962020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-16972020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6793_G>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16982020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-16992020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17002020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17012020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3821_C>A',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5055_C>T',
#   '5672_C>T',
#   '7837_A>C',
#   '14408_C>T',
#   '14700_T>C',
#   '16117_G>T',
#   '16647_G>C',
#   '23120_G>T',
#   '23403_A>G',
#   '25854_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17022020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4596_C>A',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '26801_C>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17032020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17042020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17052020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17062020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17072020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '9969_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17082020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17092020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17102020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17112020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '27798_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17122020': ['241_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23191_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17132020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17142020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17152020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17162020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '17135_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '29715_G>T'],
#  'USAWI-UW-17172020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13664_A>C',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17182020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17192020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '29402_G>T'],
#  'USAWI-UW-17202020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T'],
#  'USAWI-UW-17212020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17222020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17232020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17242020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '23403_A>G',
#   '25563_G>T'],
#  'USAWI-UW-17252020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17262020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17272020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17282020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17292020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-17302020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4960_G>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17312020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17322020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19547_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17332020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17342020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17352020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17362020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-17372020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17382020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '16741_G>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '27403_A>G',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17392020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17402020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28717_C>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17412020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4891_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '28854_C>T',
#   '29808_G>T'],
#  'USAWI-UW-17422020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17432020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14021_A>G',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29260_G>A',
#   '29402_G>T'],
#  'USAWI-UW-17442020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '7360_G>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17452020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17462020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '15654_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '25563_G>T',
#   '28681_G>T',
#   '29808_G>T'],
#  'USAWI-UW-17472020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17482020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17492020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-17502020': ['241_C>T',
#   '3037_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '23403_A>G'],
#  'USAWI-UW-17512020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17522020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '28963_T>C',
#   '29627_C>T',
#   '29808_G>T'],
#  'USAWI-UW-17532020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '14634_A>G',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '28892_C>T'],
#  'USAWI-UW-17542020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17552020': ['241_C>T',
#   '1059_C>T',
#   '1737_T>C',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '21920_G>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17562020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17572020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17582020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17592020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '28963_T>C',
#   '29627_C>T',
#   '29808_G>T'],
#  'USAWI-UW-17602020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17612020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17622020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-17632020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '16741_G>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '27403_A>G',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17642020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '28963_T>C',
#   '29627_C>T',
#   '29808_G>T'],
#  'USAWI-UW-17652020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '7420_C>T',
#   '11029_G>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29005_A>T',
#   '29808_G>T'],
#  'USAWI-UW-17662020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3885_C>T',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17672020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '28963_T>C',
#   '29627_C>T',
#   '29808_G>T'],
#  'USAWI-UW-17682020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6781_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17692020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17702020': ['241_C>T',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-17712020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17722020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '14634_A>G',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '28892_C>T'],
#  'USAWI-UW-17732020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '23403_A>G',
#   '25563_G>T'],
#  'USAWI-UW-17742020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '29402_G>T'],
#  'USAWI-UW-17752020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6781_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17762020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25290_G>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17772020': ['241_C>T',
#   '1562_T>C',
#   '2035_G>T',
#   '3037_C>T',
#   '6187_C>T',
#   '11674_C>T',
#   '11956_C>T',
#   '12025_C>T',
#   '14408_C>T',
#   '19162_G>T',
#   '19839_T>C',
#   '23403_A>G',
#   '23638_C>T',
#   '23707_C>T',
#   '28310_C>T',
#   '28881_G>A',
#   '28882_G>A',
#   '28883_G>C',
#   '29769_C>T'],
#  'USAWI-UW-17782020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20104_C>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '26801_C>T',
#   '27925_C>A',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17792020': ['241_C>T',
#   '664_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17802020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '28963_T>C',
#   '29627_C>T',
#   '29808_G>T'],
#  'USAWI-UW-17812020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '6781_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17822020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4596_C>A',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '26801_C>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17832020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28468_A>C',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17842020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '27078_C>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17852020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '11595_A>G',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17862020': ['241_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17872020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17882020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-17892020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '22015_T>C',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T'],
#  'USAWI-UW-17902020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16158_G>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-17912020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
# ...
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18202020': ['241_C>T',
#   '696_A>C',
#   '4226_C>T',
#   '7837_A>C',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-18212020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18222020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '29808_G>T'],
#  'USAWI-UW-18232020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19328_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29614_C>T',
#   '29808_G>T'],
#  'USAWI-UW-18242020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18252020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18262020': ['241_C>T',
#   '696_A>C',
#   '2037_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '7837_A>C',
#   '11541_T>G',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '25947_G>T',
#   '28977_C>T'],
#  'USAWI-UW-18272020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18282020': ['241_C>T',
#   '1562_T>C',
#   '2035_G>T',
#   '3037_C>T',
#   '6187_C>T',
#   '11674_C>T',
#   '11956_C>T',
#   '12025_C>T',
#   '14408_C>T',
#   '19162_G>T',
#   '19839_T>C',
#   '23403_A>G',
#   '23638_C>T',
#   '23707_C>T',
#   '28310_C>T',
#   '28881_G>A',
#   '28882_G>A',
#   '28883_G>C',
#   '29769_C>T'],
#  'USAWI-UW-18292020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18302020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18312020': ['203_C>T',
#   '241_C>T',
#   '370_G>T',
#   '1059_C>T',
#   '2607_C>T',
#   '3037_C>T',
#   '14408_C>T',
#   '14634_A>G',
#   '18555_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '28892_C>T'],
#  'USAWI-UW-18322020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18332020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18342020': ['241_C>T',
#   '3037_C>T',
#   '3393_C>T',
#   '4113_C>T',
#   '5907_C>T',
#   '8114_G>A',
#   '14408_C>T',
#   '21974_G>C',
#   '23191_C>T',
#   '23403_A>G',
#   '25571_C>A',
#   '26456_C>T',
#   '27534_T>C',
#   '28881_G>A',
#   '28882_G>A',
#   '28883_G>C'],
#  'USAWI-UW-18352020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18362020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18372020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-18382020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18392020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4596_C>A',
#   '7086_C>T',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '26801_C>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18402020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18412020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '13339_T>A',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '18687_C>T',
#   '19059_T>C',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-18422020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-18432020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18442020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-18452020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-18462020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-18472020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18482020': ['241_C>T',
#   '1059_C>T',
#   '1063_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '5477_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23191_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18492020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '19118_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18502020': ['241_C>T',
#   '664_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18512020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-18522020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18532020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-18542020': ['241_C>T',
#   '264_A>G',
#   '1059_C>T',
#   '2407_G>A',
#   '3037_C>T',
#   '3885_C>T',
#   '10323_A>G',
#   '13957_C>T',
#   '14408_C>T',
#   '15276_T>A',
#   '21575_C>T',
#   '22162_T>C',
#   '23403_A>G',
#   '24010_A>G',
#   '25563_G>T',
#   '28842_G>T'],
#  'USAWI-UW-18552020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '10030_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28681_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18562020': ['241_C>T',
#   '696_A>C',
#   '1427_C>T',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '6285_C>T',
#   '14408_C>T',
#   '19524_C>T',
#   '20429_C>T',
#   '23403_A>G',
#   '28977_C>T'],
#  'USAWI-UW-18572020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-18582020': ['241_C>T',
#   '696_A>C',
#   '3037_C>T',
#   '3871_G>T',
#   '3931_T>C',
#   '4226_C>T',
#   '5672_C>T',
#   '6166_G>A',
#   '6352_G>A',
#   '7837_A>C',
#   '14408_C>T',
#   '19677_G>T',
#   '23403_A>G',
#   '27276_C>T',
#   '28977_C>T'],
#  'USAWI-UW-18592020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T',
#   '29402_G>T'],
#  'USAWI-UW-18602020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18612020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18622020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '20321_A>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18632020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '27078_C>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18642020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '13339_T>A',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '18687_C>T',
#   '19059_T>C',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T'],
#  'USAWI-UW-18652020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '7745_G>T',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '14805_C>T',
#   '18424_A>G',
#   '19947_G>T',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27225_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '29402_G>T',
#   '29724_C>T'],
#  'USAWI-UW-18662020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '22015_T>C',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T'],
#  'USAWI-UW-18672020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '28963_T>C',
#   '29627_C>T',
#   '29808_G>T'],
#  'USAWI-UW-18682020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '13176_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18692020': ['241_C>T',
#   '1059_C>T',
#   '1358_G>A',
#   '3037_C>T',
#   '4633_C>T',
#   '8083_G>A',
#   '10319_C>T',
#   '10728_C>T',
#   '12473_C>T',
#   '13201_G>T',
#   '14408_C>T',
#   '14805_C>T',
#   '16748_A>G',
#   '18424_A>G',
#   '21304_C>T',
#   '22015_T>C',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-18702020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '4596_C>A',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15672_G>T',
#   '16092_C>T',
#   '16260_C>T',
#   '17721_G>T',
#   '18985_G>T',
#   '23126_G>T',
#   '23185_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25460_C>T',
#   '25563_G>T',
#   '26801_C>T',
#   '28727_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-18712020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '3773_C>T',
#   '7086_C>T',
#   '14191_T>C',
#   '14408_C>T',
#   '15654_C>T',
#   '16092_C>T',
#   '16260_C>T',
#   '23403_A>G',
#   '23900_G>C',
#   '24253_A>T',
#   '25563_G>T',
#   '28821_C>A',
#   '29808_G>T'],
#  'USAWI-UW-23232020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '7736_G>A',
#   '8083_G>A',
#   '10319_C>T',
#   '12820_A>G',
#   '14408_C>T',
#   '14805_C>T',
#   '16616_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '21638_C>T',
#   '21639_C>A',
#   '22205_G>T',
#   '22687_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '26748_A>G',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-24842020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '7736_G>A',
#   '8083_G>A',
#   '10319_C>T',
#   '12820_A>G',
#   '14408_C>T',
#   '14805_C>T',
#   '16616_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '21638_C>T',
#   '21639_C>A',
#   '22205_G>T',
#   '22687_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '26748_A>G',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-24852020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '7736_G>A',
#   '8083_G>A',
#   '10319_C>T',
#   '12820_A>G',
#   '14408_C>T',
#   '14805_C>T',
#   '16616_C>T',
#   '18424_A>G',
#   '21304_C>T',
#   '21638_C>T',
#   '21639_C>A',
#   '22205_G>T',
#   '22687_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '25907_G>T',
#   '26748_A>G',
#   '27964_C>T',
#   '28472_C>T',
#   '28869_C>T'],
#  'USAWI-UW-24862020': ['241_C>T',
#   '1059_C>T',
#   '3037_C>T',
#   '7736_G>A',
#   '8083_G>A',
#   '10319_C>T',
#   '14408_C>T',
#   '16616_C>T',
#   '21304_C>T',
#   '23403_A>G',
#   '25563_G>T',
#   '26748_A>G']}

# %%
# this function rnadomly chooses and compares two of the above lists and returns % overlap in snp identities 

def diff(lists_of_lists, repeat_times):
    percent_overlap_distribution = []
    for i in range(repeat_times):
        li1 = random.choices(lists_of_lists, k=1)
        li2 = random.choices(lists_of_lists, k=1)
        li1 = li1[0]
        li2 = li2[0]
        len1 = len(li1)
        len2 = len(li2)
        total_len = len1 + len2
        overlap = (1 - (len((list(list(set(li1)-set(li2)) + list(set(li2)-set(li1))))) / total_len)) * 100
        percent_overlap_distribution.append(overlap)
    return(percent_overlap_distribution)

# compare two particular lists 

def compare(li1, li2):
    li1 = li1[0]
    li2 = li2[0]
    len1 = len(li1)
    len2 = len(li2)
    total_len = len1 + len2
    overlap = (1 - (len((list(list(set(li1)-set(li2)) + list(set(li2)-set(li1))))) / total_len)) * 100
#     print(1 - overlap)
    return(overlap)

#

# %%
# compare roommates in dorms

roommates1 = compare(snps_in_dorms['USAWI-UW-17932020'],snps_in_dorms['USAWI-UW-18632020'])
print(roommates1)
roommates2 = compare(snps_in_dorms['USAWI-UW-18302020'],snps_in_dorms['USAWI-UW-18532020'])
print(roommates2)
roommates3 = compare(snps_in_dorms['USAWI-UW-18052020'],snps_in_dorms['USAWI-UW-16492020'])
print(roommates3)
roommates4 = compare(snps_in_dorms['USAWI-UW-18402020'],snps_in_dorms['USAWI-UW-18352020'])
print(roommates4)
roommates5 = compare(snps_in_dorms['USAWI-UW-16302020'],snps_in_dorms['USAWI-UW-18342020'])
print(roommates5)
roommates6 = compare(snps_in_dorms['USAWI-UW-16352020'],snps_in_dorms['USAWI-UW-18622020'])
print(roommates6)
roommates7 = compare(snps_in_dorms['USAWI-UW-16592020'],snps_in_dorms['USAWI-UW-18022020'])
print(roommates7)
roommates8 = compare(snps_in_dorms['USAWI-UW-18082020'],snps_in_dorms['USAWI-UW-18322020'])
print(roommates8)
roommates9 = compare(snps_in_dorms['USAWI-UW-16342020'],snps_in_dorms['USAWI-UW-16422020'])
print(roommates9)
roommates10 = compare(snps_in_dorms['USAWI-UW-16462020'],snps_in_dorms['USAWI-UW-16632020'])
print(roommates10)
roommates11 = compare(snps_in_dorms['USAWI-UW-18472020'],snps_in_dorms['USAWI-UW-18592020'])
print(roommates11)
roommates12 = compare(snps_in_dorms['USAWI-UW-17952020'],snps_in_dorms['USAWI-UW-18552020'])
print(roommates12)
roommates13 = compare(snps_in_dorms['USAWI-UW-18392020'],snps_in_dorms['USAWI-UW-18542020'])
print(roommates13)
roommates14 = compare(snps_in_dorms['USAWI-UW-17942020'],snps_in_dorms['USAWI-UW-16702020'])
print(roommates14)
roommates15 = compare(snps_in_dorms['USAWI-UW-16832020'],snps_in_dorms['USAWI-UW-17662020'])
print(roommates15)
roommates16 = compare(snps_in_dorms['USAWI-UW-17262020'],snps_in_dorms['USAWI-UW-16822020'])
print(roommates16)
roommates17 = compare(snps_in_dorms['USAWI-UW-18192020'],snps_in_dorms['USAWI-UW-18252020'])
print(roommates17)
roommates18 = compare(snps_in_dorms['USAWI-UW-17392020'],snps_in_dorms['USAWI-UW-17762020'])
print(roommates18)
roommates19 = compare(snps_in_dorms['USAWI-UW-17542020'],snps_in_dorms['USAWI-UW-17572020'])
print(roommates19)
roommates20 = compare(snps_in_dorms['USAWI-UW-17512020'],snps_in_dorms['USAWI-UW-17442020'])
print(roommates20)
roommates21 = compare(snps_in_dorms['USAWI-UW-16852020'],snps_in_dorms['USAWI-UW-17252020'])
print(roommates21)
roommates22 = compare(snps_in_dorms['USAWI-UW-17162020'],snps_in_dorms['USAWI-UW-17602020'])
print(roommates22)
roommates23 = compare(snps_in_dorms['USAWI-UW-17752020'],snps_in_dorms['USAWI-UW-17812020'])
print(roommates23)
roommates24 = compare(snps_in_dorms['USAWI-UW-17362020'],snps_in_dorms['USAWI-UW-18152020'])
print(roommates24)
roommates25 = compare(snps_in_dorms['USAWI-UW-17452020'],snps_in_dorms['USAWI-UW-17422020'])
print(roommates25)
roommates26 = compare(snps_in_dorms['USAWI-UW-17032020'],snps_in_dorms['USAWI-UW-17702020'])
print(roommates26)
roommates27 = compare(snps_in_dorms['USAWI-UW-17382020'],snps_in_dorms['USAWI-UW-17632020'])
print(roommates27)
roommates28 = compare(snps_in_dorms['USAWI-UW-16862020'],snps_in_dorms['USAWI-UW-18062020'])
print(roommates28)
roommates29 = compare(snps_in_dorms['USAWI-UW-17502020'],snps_in_dorms['USAWI-UW-17532020'])
print(roommates29)
roommates30 = compare(snps_in_dorms['USAWI-UW-18232020'],snps_in_dorms['USAWI-UW-17352020'])
print(roommates30)
roommates31 = compare(snps_in_dorms['USAWI-UW-17072020'],snps_in_dorms['USAWI-UW-17212020'])
print(roommates31)
roommates32 = compare(snps_in_dorms['USAWI-UW-16742020'],snps_in_dorms['USAWI-UW-16752020'])
print(roommates32)
roommates33 = compare(snps_in_dorms['USAWI-UW-16972020'],snps_in_dorms['USAWI-UW-16782020'])
print(roommates33)
# Out:
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 71.42857142857143
# 100.0
# 100.0
# 100.0
# 100.0

# %%
percent_overlap_10000 = diff(list_of_snps, 33930)

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3, 20)

ax1 = fig.add_subplot(gs[0,0:9]) 

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)  

# plot distribution
plt.hist(percent_overlap_10000, 10, color='grey')

# plot household pairs
plt.axvline(x=roommates1, color='#c5050c')
plt.axvline(x=roommates29, color='#c5050c')

textstr1 = 'n=32'
textstr2 = 'n=1'


ax1.set_ylabel('# of pairwise comparisons',fontsize=12)
ax1.set_xlabel('% overlap in SNP identities',fontsize=12)

ax1.tick_params(axis='both', which='major', labelsize=12)
ax1.tick_params(axis='both', which='minor', labelsize=12)

#legend
A = mpatches.Patch(color='#c5050c', label='Roommates')
B = mpatches.Patch(color='grey', label='Random pairs')

ax1.text(0.92, 1.09, textstr1, transform=ax1.transAxes, fontsize=14,
        verticalalignment='top')
ax1.text(0.625, 1.09, textstr2, transform=ax1.transAxes, fontsize=14,
        verticalalignment='top')


plt.legend(handles=(A, B), frameon=False, bbox_to_anchor=[1, 1.1], fontsize=12)


plt.savefig("figures/within-vs-between-roomies.svg", bbox_inches='tight', dpi=300)
plt.savefig("figures/within-vs-between-household.png", bbox_inches='tight', dpi=300)

# %%
unique_snps = get_unique_snps('VCFs/Cleaned/', cleaned)
unique_snps
# Out:
#            SNP
# 0      241_C>T
# 1     1059_C>T
# 2     3037_C>T
# 3     3773_C>T
# 4     6793_G>T
# ..         ...
# 176  21638_C>T
# 177  21639_C>A
# 178  22205_G>T
# 179  22687_C>T
# 180  26748_A>G
#
# [181 rows x 1 columns]

# %%
nextclade = pd.read_csv('../nextclade.csv', sep=';')
nextclade = nextclade[['seqName', 'substitutions']]
nextclade.to_csv('../nextclade_abridged.csv',sep=',')

# hh5 = [C241T,T833C,C1059T,C3037T,C14408T,G17298T,G20087A,A20097T,A23403G,G25563T,C27964T,C241T,A696C,C1059T,C3037T,G8561A,C14408T,A23403G,A23845T,G25563T,C27964T]

# Counter(hh5)
